# %%
import pandas as pd
df = pd.read_csv('../raw_data/df_main_new.csv')

# %%
df
# Out:
#          lat_cen    lon_cen  hv001  oldlabel  cats
# 0      34.382727  73.848621    101         4     2
# 1      34.404180  74.294310    102         2     4
# 2      34.455160  74.364586    103         2     3
# 3      34.559398  74.068008    104         4     2
# 4      34.457346  74.094578    105         5     1
# ...          ...        ...    ...       ...   ...
# 30047  23.191093  88.056766  93238         3     2
# 30048  23.395079  88.139663  93239         4     1
# 30049  23.205505  88.308991  93240         3     3
# 30050  23.097570  88.092668  93241         5     1
# 30051  23.520542  87.768405  93242         4     1
#
# [30052 rows x 5 columns]

# %%
import requests
N = len(df)
key='AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE'
size = '1024x1024'
zoom = '16'
maptype = 'satellite'
path = '/Volumes/GoogleDrive/My Drive/povertymapper1024/'



for i in range(21, 10000, 1):
    lat = df.lat_cen[i]
    lon = df.lon_cen[i]
    label = df.cats[i]
    url = f'https://maps.googleapis.com/maps/api/staticmap?center={lat},{lon}&zoom={zoom}&size={size}&key={key}&maptype={maptype}'
    image = requests.get(url).content
    print(i)
    print(url)
    f = open(path + '/' + str(label) + '/' + str(i) + '.png', 'wb')
    f.write(image)
    f.close()
# Out:
# 21
# https://maps.googleapis.com/maps/api/staticmap?center=34.466532,74.416351&zoom=16&size=1024x1024&key=AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE&maptype=satellite
# 22
# https://maps.googleapis.com/maps/api/staticmap?center=34.462301,74.227372&zoom=16&size=1024x1024&key=AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE&maptype=satellite
# 23
# https://maps.googleapis.com/maps/api/staticmap?center=34.453795,74.341888&zoom=16&size=1024x1024&key=AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE&maptype=satellite
# 24
# https://maps.googleapis.com/maps/api/staticmap?center=34.556738,74.490097&zoom=16&size=1024x1024&key=AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE&maptype=satellite
# 25
# https://maps.googleapis.com/maps/api/staticmap?center=34.49073,74.254084&zoom=16&size=1024x1024&key=AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE&maptype=satellite
# 26
# https://maps.googleapis.com/maps/api/staticmap?center=34.383044,74.177576&zoom=16&size=1024x1024&key=AIzaSyBDpJ0xlehhbOeafQ-LLCXDDPypeYIPrUE&maptype=satellite
# 27
# ...
